# %%
import os
import pandas as pd
import numpy as np

# %%
from paths import PROLINE_RAW_DATA_PATH

# plt.rcParams.update({
#     "text.usetex": True
# })

files = []

for file in os.scandir(PROLINE_RAW_DATA_PATH):
    if file.is_file():
        files.append(file)


df = pd.read_excel(files[0], sheet_name='CD8')

# %%
from paths import PROLINE_RAW_DATA_PATH

# plt.rcParams.update({
#     "text.usetex": True
# })

files = []

for file in os.scandir(PROLINE_RAW_DATA_PATH):
    if file.is_file():
        files.append(file)


df = pd.read_excel(files[0], sheet_name='CD8')
df['Description'] = df.loc[:, 'Description'].dropna().apply(lambda x: x[:x.find('OS') - 1])
df = df.set_index('Description').dropna()

# %%
df.loc['Myosin-9', 'K1':'K7'].mean()
# Out:
# 57.714285714285715

# %%
df.loc[:,'K1':'K7'].mean(axis=1)
# Out:
# Description
# Myosin-9                                                               57.714286
# Filamin-A                                                              19.000000
# Vimentin                                                              103.571429
# Keratin, type II cytoskeletal 1                                       113.000000
# Plastin-2                                                              62.142857
#                                                                          ...
# High mobility group nucleosome-binding domain-containing protein 4      0.000000
# Ras/Rap GTPase-activating protein SynGAP                                0.142857
# Torsin-1A-interacting protein 1                                         0.142857
# Nucleolus and neural progenitor protein                                 0.000000
# Solute carrier family 12 member 3                                       0.142857
# Length: 509, dtype: float64

# %%
df['new'] = df.loc[:, 'K1':'K7'].mean(axis=1)

# %%
df.columns = [*df.columns[:-1], 'mean']
df.head()
# Out:
#                                     K1     K2     K3    K4     K5     K6  \
# Description
# Myosin-9                           3.0   67.0   30.0   3.0  113.0  134.0
# Filamin-A                          5.0   12.0    0.0   0.0   44.0   39.0
# Vimentin                          64.0  102.0   82.0  27.0  143.0  170.0
# Keratin, type II cytoskeletal 1  209.0  154.0  112.0  52.0  108.0  140.0
# Plastin-2                         44.0   45.0   27.0   0.0   90.0  130.0
#
#                                     K7     Z1     Z3     Z4  ...      K7.1  \
# Description                                                  ...
# Myosin-9                          54.0   88.0   75.0  150.0  ... -1.163976
# Filamin-A                         33.0   30.0   15.0   84.0  ... -0.451461
# Vimentin                         137.0  105.0  105.0  138.0  ... -0.005256
# Keratin, type II cytoskeletal 1   16.0  135.0  142.0    0.0  ... -2.342075
# Plastin-2                         99.0   61.0   85.0  141.0  ... -0.127200
#
#                                      Z1.1      Z3.1      Z4.1      Z5.1  \
# Description
# Myosin-9                         0.608575  0.377962  1.377962  0.358597
# Filamin-A                        0.658963 -0.341037  2.144390  0.211504
# Vimentin                         0.019763  0.019763  0.414042  0.327886
# Keratin, type II cytoskeletal 1  0.256637  0.329568  0.000000  0.987176
# Plastin-2                       -0.026779  0.451874  1.182035 -0.124627
#
#                                      Z6.1      Z7.1      Z8.1      Z9.1  \
# Description
# Myosin-9                         0.608575  0.718999  1.778500  1.793000
# Filamin-A                        1.337035  0.881356  2.479993  0.144390
# Vimentin                         0.445069  0.099934  0.905431  0.764949
# Keratin, type II cytoskeletal 1 -2.235216 -0.962198  0.000000 -0.775785
# Plastin-2                        0.581642  0.597072  1.634940  1.182035
#
#                                        mean
# Description
# Myosin-9                          57.714286
# Filamin-A                         19.000000
# Vimentin                         103.571429
# Keratin, type II cytoskeletal 1  113.000000
# Plastin-2                         62.142857
#
# [5 rows x 47 columns]

# %%
df['fc'] = df.loc[:,'K1':'K7'].apply(lambda row: 1)
df.head()
# Out:
#                                     K1     K2     K3    K4     K5     K6  \
# Description
# Myosin-9                           3.0   67.0   30.0   3.0  113.0  134.0
# Filamin-A                          5.0   12.0    0.0   0.0   44.0   39.0
# Vimentin                          64.0  102.0   82.0  27.0  143.0  170.0
# Keratin, type II cytoskeletal 1  209.0  154.0  112.0  52.0  108.0  140.0
# Plastin-2                         44.0   45.0   27.0   0.0   90.0  130.0
#
#                                     K7     Z1     Z3     Z4  ...      Z1.1  \
# Description                                                  ...
# Myosin-9                          54.0   88.0   75.0  150.0  ...  0.608575
# Filamin-A                         33.0   30.0   15.0   84.0  ...  0.658963
# Vimentin                         137.0  105.0  105.0  138.0  ...  0.019763
# Keratin, type II cytoskeletal 1   16.0  135.0  142.0    0.0  ...  0.256637
# Plastin-2                         99.0   61.0   85.0  141.0  ... -0.026779
#
#                                      Z3.1      Z4.1      Z5.1      Z6.1  \
# Description
# Myosin-9                         0.377962  1.377962  0.358597  0.608575
# Filamin-A                       -0.341037  2.144390  0.211504  1.337035
# Vimentin                         0.019763  0.414042  0.327886  0.445069
# Keratin, type II cytoskeletal 1  0.329568  0.000000  0.987176 -2.235216
# Plastin-2                        0.451874  1.182035 -0.124627  0.581642
#
#                                      Z7.1      Z8.1      Z9.1        mean  fc
# Description
# Myosin-9                         0.718999  1.778500  1.793000   57.714286 NaN
# Filamin-A                        0.881356  2.479993  0.144390   19.000000 NaN
# Vimentin                         0.099934  0.905431  0.764949  103.571429 NaN
# Keratin, type II cytoskeletal 1 -0.962198  0.000000 -0.775785  113.000000 NaN
# Plastin-2                        0.597072  1.634940  1.182035   62.142857 NaN
#
# [5 rows x 48 columns]
